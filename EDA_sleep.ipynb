# %%
data_dict = {'email' : '이메일',
# 'date' : '요약 날짜',
# 'check' : '착용 여부 체크',
'nonwear' : '미착용 시간 체크',
'activity_average_met' : '하루간 평균 MET',
'activity_cal_active' : '하루간 활동 칼로리',
'activity_cal_total' : '하루간 총 사용 칼로리',
'activity_class_5min' : '하루간 5분당 활동 로그',
'activity_daily_movement' : '매일 움직인 거리',
'activity_day_end' : '활동 종료 시간',
'activity_day_start' : '활동 시작 시간',
'activity_high' : '고강도 활동 시간',
'activity_inactive' : '비활동 시간',
'activity_inactivity_alerts' : '비활동 알람 횟수',
'active_low' : '저강도 활동 시간',
'activity_medium' : '중강도 활동 시간',
'activity_met_1min' : '하루간 1분 당 MET 로그',
'activity_met_min_high' : '하루간 고강도 활동 MET',
'activity_met_min_inactive' : '하루간 비활동 MET',
'activity_met_min_low' : '하루간 저강도 활동 MET',
'activity_met_min_medium' : '하루간 중강도 활동 MET',
'activity_non_wear' : '미착용 시간',
'activity_rest' : '휴식 시간',
'activity_score' : '활동 점수',
'activity_score_meet_daily_targets' : '활동 목표달성 점수',
'activity_score_move_every_hour' : '매 시간 당 활동유지 점수',
'activity_score_recovery_time' : '회복시간 점수',
'activity_score_stay_active' : '활동 유지 점수',
'activity_score_training_frequency' : '운동 빈도 점수',
'activity_score_training_volume' : '운동 빈도 점수',
'activity_steps' : '매일 걸음 수',
'activity_total' : '활동 총 시간(분)', 
'sleep_awake' : '깬 시간', 
'sleep_bedtime_end' : '잠 종료시간', 
'sleep_bedtime_start' : '잠 시작시간', 
'sleep_breatj_average' : '분단 평균 호흡 수', 
'sleep_deep' : '깊은 수면 시간', 
'sleep_duration' : '잠 시간', 
'sleep_efficiency' : '수면 효율', 
'sleep_hr_5min' : '5분 당 심박동 로그', 
'sleep_hr_average' : '분당 평균 심박동 수', 
'sleep_hr_lowest' : '분당 낮은 심박동 수', 
'sleep_hypnogram_5min' : '수면 상태 로그', 
'sleep_is_longest' : '본 수면 여부', 
'sleep_light' : '가벼운 수면 시간', 
'sleep_midpoint_at_delta' : '수면 중간점 시간 델타', 
'sleep_midpoint_time' : '수면 중간점 시간', 
'sleep_onset_latency' : '수면 잠복 시간', 
'sleep_period_id' : '수면 식별 아이디', 
'sleep_rem' : '램수면 시간', 
'sleep_restless' : '뒤척임 비율', 
'sleep_rmssd' : '평균 심박동변동', 
'sleep_rmssd_5min' : '5분 당 심박동변동 로그', 
'sleep_score' : '수면 종합 점수', 
'sleep_score_alignment' : '수면 시기 점수', 
'sleep_score_deep' : '깊은 수면 점수', 
'sleep_score_disturbances' : '수면 방해 점수', 
'sleep_score_efficiency' : '수면 효율 점수', 
'sleep_score_latency' : '수면 잠복 점수', 
'sleep_score_rem' : '램수면 점수', 
'sleep_score_total' : '수면 시간 기여 점수', 
'sleep_temperature_delta' : '피부 온도 편차', 
'sleep_temperature_deviation' : '피부 온도 편차',
'sleep_temperature_trend_deviation' : '피부 온도 경향 편차',
'timezone' : '시간 장소 정보',
'sleep_total' : '수면 시간'}

# %%
import os 
from glob import glob 
import pandas as pd 
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %%
gait = pd.read_csv('/Users/sehwan/Desktop/datasets/dementia/data/1.Training/raw/gait/train_activity.csv')
cog = pd.read_csv('/Users/sehwan/Desktop/datasets/dementia/data/1.Training/raw/cognitive/train_mmse.csv')
slp = pd.read_csv('/Users/sehwan/Desktop/datasets/dementia/data/1.Training/raw/sleep/train_sleep.csv')

gait_label = pd.read_csv('/Users/sehwan/Desktop/datasets/dementia/data/1.Training/label/gait/training_label.csv')
cog_label = pd.read_csv('/Users/sehwan/Desktop/datasets/dementia/data/1.Training/label/2.수면/training_label.csv')
slp_label = pd.read_csv('/Users/sehwan/Desktop/datasets/dementia/data/1.Training/label/3.인지기능/training_label.csv')
# df.head()
# raw.iloc[:2, :].T
len(gait), len(cog), len(slp)
# Out:
# (9705, 141, 9705)

# %%
label[label['SAMPLE_EMAIL'] == 'nia+315@rowan.kr']['DIAG_NM'].values[0]
# Out:
# 'CN'

# %%
print(len(raw))
raw = pd.merge(raw, label, left_on='EMAIL', right_on='SAMPLE_EMAIL', how='right')
print(len(raw))
# Out:
# 9705
# 9705

# %%
label.iloc[:3, :].T
# Out:
#                              0                 1                 2
# SAMPLE_EMAIL  nia+315@rowan.kr  nia+014@rowan.kr  nia+220@rowan.kr
# DIAG_NM                     CN               MCI                CN

# %%
raw.isna().sum()
# Out:
# EMAIL                                      0
# activity_average_met                       0
# activity_cal_active                        0
# activity_cal_total                         0
# activity_class_5min                        0
# activity_daily_movement                    0
# activity_day_end                           0
# activity_day_start                         0
# activity_high                              0
# activity_inactive                          0
# activity_inactivity_alerts                 0
# activity_low                               0
# activity_medium                            0
# activity_met_1min                          0
# activity_met_min_high                      0
# activity_met_min_inactive                  0
# activity_met_min_low                       0
# activity_met_min_medium                    0
# activity_non_wear                          0
# activity_rest                              0
# activity_score                             0
# activity_score_meet_daily_targets          0
# activity_score_move_every_hour             0
# activity_score_recovery_time               0
# activity_score_stay_active                 0
# activity_score_training_frequency          0
# activity_score_training_volume             0
# activity_steps                             0
# activity_total                             0
# CONVERT(activity_class_5min USING utf8)    0
# CONVERT(activity_met_1min USING utf8)      0
# SAMPLE_EMAIL                               0
# DIAG_NM                                    0
# dtype: int64

# %%
msno.bar(df=raw, color=(0.1, 0.6, 0.8), figsize=(10, 6))
# Out:
# <Axes: >

# %%
# label.iloc[3, :].T
(
    raw['DIAG_NM']
    .value_counts()
    .plot(kind='barh')
)
# Dem -> 치매
# MCI -> 경도 인지장애
# CN -> 인지 정상
# Out:
# <Axes: >

# %%
# raw['date']
raw.iloc[:3, :].T
# Out:
#                                                                                          0  \
# EMAIL                                                                     nia+315@rowan.kr
# activity_average_met                                                               1.71875
# activity_cal_active                                                                    796
# activity_cal_total                                                                    2948
# activity_class_5min                                                                    ...
# activity_daily_movement                                                              14663
# activity_day_end                                                 2020-10-19T03:59:59+09:00
# activity_day_start                                               2020-10-18T04:00:00+09:00
# activity_high                                                                           23
# activity_inactive                                                                      614
# activity_inactivity_alerts                                                               2
# activity_low                                                                           343
# activity_medium                                                                         74
# activity_met_1min                                                                      ...
# activity_met_min_high                                                                  184
# activity_met_min_inactive                                                                6
# activity_met_min_low                                                                   241
# activity_met_min_medium                                                                222
# activity_non_wear                                                                        0
# activity_rest                                                                          386
# activity_score                                                                          88
# activity_score_meet_daily_targets                                                       95
# activity_score_move_every_hour                                                          78
# activity_score_recovery_time                                                            86
# activity_score_stay_active                                                              70
# activity_score_training_frequency                                                      100
# activity_score_training_volume                                                         100
# activity_steps                                                                       16188
# activity_total                                                                         440
# CONVERT(activity_class_5min USING utf8)  2/2/2/3/3/2/3/2/3/2/2/2/2/2/2/2/2/2/2/2/2/3/2/...
# CONVERT(activity_met_1min USING utf8)    1.1/0.9/0.9/0.9/0.9/1.4/1/1.5/2.4/1.5/2.5/1.5/...
# SAMPLE_EMAIL                                                              nia+315@rowan.kr
# DIAG_NM                                                                                 CN
#
#                                                                                          1  \
# EMAIL                                                                     nia+315@rowan.kr
# activity_average_met                                                               1.59375
# activity_cal_active                                                                    635
# activity_cal_total                                                                    2777
# activity_class_5min                                                                    ...
# activity_daily_movement                                                              12630
# activity_day_end                                                 2020-10-20T03:59:59+09:00
# activity_day_start                                               2020-10-19T04:00:00+09:00
# activity_high                                                                            0
# activity_inactive                                                                      536
# activity_inactivity_alerts                                                               0
# activity_low                                                                           323
# activity_medium                                                                         81
# activity_met_1min                                                                      ...
# activity_met_min_high                                                                    0
# activity_met_min_inactive                                                               10
# activity_met_min_low                                                                   271
# activity_met_min_medium                                                                240
# activity_non_wear                                                                       60
# activity_rest                                                                          440
# activity_score                                                                          89
# activity_score_meet_daily_targets                                                       95
# activity_score_move_every_hour                                                         100
# activity_score_recovery_time                                                            78
# activity_score_stay_active                                                              80
# activity_score_training_frequency                                                      100
# activity_score_training_volume                                                         100
# activity_steps                                                                       15447
# activity_total                                                                         404
# CONVERT(activity_class_5min USING utf8)  1/1/1/2/3/3/2/2/2/2/2/2/2/2/2/2/2/2/2/2/2/3/2/...
# CONVERT(activity_met_1min USING utf8)    0.9/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0....
# SAMPLE_EMAIL                                                              nia+315@rowan.kr
# DIAG_NM                                                                                 CN
#
#                                                                                          2
# EMAIL                                                                     nia+315@rowan.kr
# activity_average_met                                                               1.53125
# activity_cal_active                                                                    490
# activity_cal_total                                                                    2636
# activity_class_5min                                                                    ...
# activity_daily_movement                                                               8344
# activity_day_end                                                 2020-10-21T03:59:59+09:00
# activity_day_start                                               2020-10-20T04:00:00+09:00
# activity_high                                                                            2
# activity_inactive                                                                      595
# activity_inactivity_alerts                                                               0
# activity_low                                                                           359
# activity_medium                                                                         51
# activity_met_1min                                                                      ...
# activity_met_min_high                                                                   18
# activity_met_min_inactive                                                               11
# activity_met_min_low                                                                   215
# activity_met_min_medium                                                                158
# activity_non_wear                                                                        0
# activity_rest                                                                          433
# activity_score                                                                          81
# activity_score_meet_daily_targets                                                       78
# activity_score_move_every_hour                                                         100
# activity_score_recovery_time                                                            71
# activity_score_stay_active                                                              71
# activity_score_training_frequency                                                      100
# activity_score_training_volume                                                         100
# activity_steps                                                                       11623
# activity_total                                                                         412
# CONVERT(activity_class_5min USING utf8)  1/1/1/2/3/3/3/2/3/2/2/2/2/2/2/2/2/2/2/2/2/2/3/...
# CONVERT(activity_met_1min USING utf8)    1.1/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0.9/0....
# SAMPLE_EMAIL                                                              nia+315@rowan.kr
# DIAG_NM                                                                                 CN

# %%
def violin(df, col):
    fig = px.violin(df, y=col, x="DIAG_NM", color="DIAG_NM", box=True, template = 'plotly_dark')
    fig.update_layout(autosize=False, width=900, height=500)
    return fig.show()

def kde(df, col):
    grid = sns.FacetGrid(df, hue="DIAG_NM", height = 6, aspect=2)
    grid.map(sns.kdeplot, col)
    grid.add_legend()

# %%
violin(raw, 'activity_cal_active')

kde(raw, 'activity_cal_active')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> violin(raw, 'activity_cal_active')
#       <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> kde(raw, 'activity_cal_active')
#
# /Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> def violin(df, col):
# ----> <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     fig = px.violin(df, y=col, x="DIAG_NM", color="DIAG_NM", box=True, template = 'plotly_dark')
#       <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     fig.update_layout(autosize=False, width=900, height=500)
#       <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     return fig.show()
#
# NameError: name 'px' is not defined

# %%
violin(raw, 'activity_cal_total')

kde(raw, 'activity_cal_total')

# %%
numerical_features_to_investigate = ['activity_average_met',
'activity_cal_active',
'activity_cal_total',
# 'activity_class_5min',
'activity_daily_movement',
'activity_day_end',
'activity_day_start',
'activity_high',
'activity_inactive',
'activity_inactivity_alerts',
'activity_low',
'activity_medium',
# 'activity_met_1min',
'activity_met_min_high',
'activity_met_min_inactive',
'activity_met_min_low',
'activity_met_min_medium',
'activity_non_wear',
'activity_rest',
'activity_score',
'activity_score_meet_daily_targets',
'activity_score_move_every_hour',
'activity_score_recovery_time',
'activity_score_stay_active',
'activity_score_training_frequency',
'activity_score_training_volume',
'activity_steps',
'activity_total',]

# %%
raw['DIAG_NM']
# Out:
# 0        CN
# 1        CN
# 2        CN
# 3        CN
# 4        CN
#        ...
# 9700    Dem
# 9701    Dem
# 9702    Dem
# 9703    Dem
# 9704    Dem
# Name: DIAG_NM, Length: 9705, dtype: object

# %%
raw = (
        raw
        .assign(DIAG_NM_num=lambda x : x['DIAG_NM'].apply(lambda y : 0 if y == 'CN' else 1 if y == 'MCI' else 2))
        # .assign(FraudFound=lambda x : x['DIAG_NM'].apply(lambda y : 1 if y=='Yes' else 0))
    )

# %%
(
    pd.concat(
        [
            (
                raw
                .loc[:, numerical_features_to_investigate]
            ),
            (
                raw['DIAG_NM_num']
            ),
        ],
        axis=1
    )
    .corr()
    .style.background_gradient()
)
# Out:
# <style type="text/css">
# #T_61d03_row0_col0, #T_61d03_row1_col1, #T_61d03_row2_col2, #T_61d03_row3_col3, #T_61d03_row4_col4, #T_61d03_row4_col5, #T_61d03_row5_col4, #T_61d03_row5_col5, #T_61d03_row6_col6, #T_61d03_row7_col7, #T_61d03_row8_col8, #T_61d03_row9_col9, #T_61d03_row10_col10, #T_61d03_row11_col11, #T_61d03_row12_col12, #T_61d03_row13_col13, #T_61d03_row14_col14, #T_61d03_row15_col15, #T_61d03_row16_col16, #T_61d03_row17_col17, #T_61d03_row18_col18, #T_61d03_row19_col19, #T_61d03_row20_col20, #T_61d03_row21_col21, #T_61d03_row22_col22, #T_61d03_row23_col23, #T_61d03_row24_col24, #T_61d03_row25_col25, #T_61d03_row26_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col1, #T_61d03_row0_col3, #T_61d03_row2_col1, #T_61d03_row3_col0, #T_61d03_row6_col11, #T_61d03_row11_col6 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col2, #T_61d03_row2_col24 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col4, #T_61d03_row0_col5, #T_61d03_row2_col20, #T_61d03_row12_col15, #T_61d03_row16_col18, #T_61d03_row25_col16, #T_61d03_row26_col4, #T_61d03_row26_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_61d03_row0_col6 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col7, #T_61d03_row10_col7, #T_61d03_row19_col12, #T_61d03_row26_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_61d03_row0_col8, #T_61d03_row6_col23, #T_61d03_row11_col13, #T_61d03_row15_col7, #T_61d03_row20_col21 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_61d03_row0_col9 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col10, #T_61d03_row0_col14, #T_61d03_row25_col2 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col11, #T_61d03_row14_col9 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col12 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_61d03_row0_col13, #T_61d03_row23_col17 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col15, #T_61d03_row7_col14, #T_61d03_row13_col15 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_61d03_row0_col16, #T_61d03_row4_col26, #T_61d03_row5_col26, #T_61d03_row7_col1, #T_61d03_row7_col3, #T_61d03_row7_col13, #T_61d03_row7_col15, #T_61d03_row7_col17, #T_61d03_row7_col21, #T_61d03_row7_col23, #T_61d03_row7_col24, #T_61d03_row7_col25, #T_61d03_row8_col19, #T_61d03_row13_col4, #T_61d03_row13_col5, #T_61d03_row14_col20, #T_61d03_row16_col0, #T_61d03_row16_col2, #T_61d03_row16_col9, #T_61d03_row16_col12, #T_61d03_row16_col25, #T_61d03_row19_col8, #T_61d03_row20_col2, #T_61d03_row20_col6, #T_61d03_row20_col10, #T_61d03_row20_col11, #T_61d03_row20_col14, #T_61d03_row20_col18, #T_61d03_row20_col22, #T_61d03_row21_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_61d03_row0_col17, #T_61d03_row2_col17, #T_61d03_row6_col24, #T_61d03_row13_col10, #T_61d03_row14_col22, #T_61d03_row21_col2, #T_61d03_row25_col23 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col18, #T_61d03_row3_col18, #T_61d03_row23_col10 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col19, #T_61d03_row1_col22, #T_61d03_row10_col13, #T_61d03_row11_col21, #T_61d03_row17_col2, #T_61d03_row23_col19 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col20 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_61d03_row0_col21, #T_61d03_row10_col21 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col22, #T_61d03_row4_col7, #T_61d03_row5_col7 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col23, #T_61d03_row20_col7 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col24, #T_61d03_row24_col0 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col25 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_61d03_row0_col26, #T_61d03_row11_col26 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_61d03_row1_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col2 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col3, #T_61d03_row3_col1 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col4, #T_61d03_row1_col5, #T_61d03_row3_col4, #T_61d03_row3_col5, #T_61d03_row7_col9, #T_61d03_row7_col11, #T_61d03_row9_col15, #T_61d03_row9_col16, #T_61d03_row16_col13, #T_61d03_row18_col4, #T_61d03_row18_col5, #T_61d03_row25_col15 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_61d03_row1_col6, #T_61d03_row3_col6, #T_61d03_row17_col14, #T_61d03_row23_col9 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col7, #T_61d03_row7_col19, #T_61d03_row8_col12, #T_61d03_row13_col7, #T_61d03_row15_col0, #T_61d03_row15_col10, #T_61d03_row15_col14 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_61d03_row1_col8, #T_61d03_row3_col8, #T_61d03_row4_col16, #T_61d03_row5_col16, #T_61d03_row6_col22, #T_61d03_row8_col20, #T_61d03_row12_col20 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_61d03_row1_col9, #T_61d03_row9_col1, #T_61d03_row9_col24, #T_61d03_row24_col9, #T_61d03_row25_col21 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col10, #T_61d03_row10_col1, #T_61d03_row22_col23, #T_61d03_row23_col22 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col11, #T_61d03_row11_col10 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col12, #T_61d03_row8_col14, #T_61d03_row24_col12 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_61d03_row1_col13, #T_61d03_row2_col10, #T_61d03_row13_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col14, #T_61d03_row3_col10, #T_61d03_row10_col3, #T_61d03_row14_col1 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col15, #T_61d03_row2_col15, #T_61d03_row8_col17, #T_61d03_row12_col16, #T_61d03_row17_col26, #T_61d03_row22_col26 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_61d03_row1_col16, #T_61d03_row4_col15, #T_61d03_row5_col15, #T_61d03_row26_col6 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_61d03_row1_col17, #T_61d03_row21_col14 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col18, #T_61d03_row21_col3, #T_61d03_row21_col24, #T_61d03_row21_col25, #T_61d03_row23_col0, #T_61d03_row25_col18 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col19, #T_61d03_row3_col17, #T_61d03_row3_col19, #T_61d03_row21_col16, #T_61d03_row24_col22 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col20, #T_61d03_row3_col20, #T_61d03_row7_col18, #T_61d03_row7_col22, #T_61d03_row7_col26, #T_61d03_row18_col26, #T_61d03_row20_col1, #T_61d03_row20_col23 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_61d03_row1_col21, #T_61d03_row13_col21 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col23 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col24, #T_61d03_row24_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col25, #T_61d03_row25_col1, #T_61d03_row25_col3 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_61d03_row1_col26, #T_61d03_row8_col18, #T_61d03_row24_col26, #T_61d03_row25_col26 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_61d03_row2_col0, #T_61d03_row3_col2, #T_61d03_row10_col24, #T_61d03_row14_col24, #T_61d03_row24_col10 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_61d03_row2_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_61d03_row2_col4, #T_61d03_row2_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_61d03_row2_col6, #T_61d03_row4_col21, #T_61d03_row5_col21, #T_61d03_row12_col25, #T_61d03_row14_col6 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_61d03_row2_col7, #T_61d03_row11_col16 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_61d03_row2_col8 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_61d03_row2_col9 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_61d03_row2_col11, #T_61d03_row15_col8, #T_61d03_row19_col0, #T_61d03_row19_col13 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_61d03_r

# %%
# !pip install pycaret==3.0.0rc4
# !pip install 
# !pip install pyod
# from pyod.models.auto_encoder import AutoEncoder

# %%
# 활동시간
#하루 활동 시간에 대해서는 아무런 특이 data 없음
raw['activity_day_start'], raw['activity_day_end']
# Out:
# (0       2020-10-18T04:00:00+09:00
#  1       2020-10-19T04:00:00+09:00
#  2       2020-10-20T04:00:00+09:00
#  3       2020-10-21T04:00:00+09:00
#  4       2020-10-22T04:00:00+09:00
#                    ...
#  9700    2020-12-31T04:00:00+09:00
#  9701    2021-01-01T04:00:00+09:00
#  9702    2021-01-02T04:00:00+09:00
#  9703    2021-01-04T04:00:00+09:00
#  9704    2021-01-05T04:00:00+09:00
#  Name: activity_day_start, Length: 9705, dtype: object,
#  0       2020-10-19T03:59:59+09:00
#  1       2020-10-20T03:59:59+09:00
#  2       2020-10-21T03:59:59+09:00
#  3       2020-10-22T03:59:59+09:00
#  4       2020-10-23T03:59:59+09:00
#                    ...
#  9700    2021-01-01T03:59:59+09:00
#  9701    2021-01-02T03:59:59+09:00
#  9702    2021-01-03T03:59:59+09:00
#  9703    2021-01-05T03:59:59+09:00
#  9704    2021-01-06T03:59:59+09:00
#  Name: activity_day_end, Length: 9705, dtype: object)

# %%
raw = (
   raw
   .assign(activity_day_start=lambda x : pd.to_datetime(x['activity_day_start']))
   .assign(activity_day_end=lambda x : pd.to_datetime(x['activity_day_end']))
   .assign(activity_day_time=lambda x : x['activity_day_end'] - x['activity_day_start'])
)
# raw.loc[:['activity_day_start', 'activity_day_end', 'activity_day_time']]

# %%
raw.loc[:, ['activity_day_start', 'activity_day_end', 'activity_day_time']]
# Out:
#             activity_day_start          activity_day_end activity_day_time
# 0    2020-10-18 04:00:00+09:00 2020-10-19 03:59:59+09:00   0 days 23:59:59
# 1    2020-10-19 04:00:00+09:00 2020-10-20 03:59:59+09:00   0 days 23:59:59
# 2    2020-10-20 04:00:00+09:00 2020-10-21 03:59:59+09:00   0 days 23:59:59
# 3    2020-10-21 04:00:00+09:00 2020-10-22 03:59:59+09:00   0 days 23:59:59
# 4    2020-10-22 04:00:00+09:00 2020-10-23 03:59:59+09:00   0 days 23:59:59
# ...                        ...                       ...               ...
# 9700 2020-12-31 04:00:00+09:00 2021-01-01 03:59:59+09:00   0 days 23:59:59
# 9701 2021-01-01 04:00:00+09:00 2021-01-02 03:59:59+09:00   0 days 23:59:59
# 9702 2021-01-02 04:00:00+09:00 2021-01-03 03:59:59+09:00   0 days 23:59:59
# 9703 2021-01-04 04:00:00+09:00 2021-01-05 03:59:59+09:00   0 days 23:59:59
# 9704 2021-01-05 04:00:00+09:00 2021-01-06 03:59:59+09:00   0 days 23:59:59
#
# [9705 rows x 3 columns]

# %%
(
    raw['activity_day_time']
    .value_counts()
)
# Out:
# 0 days 23:59:59    9705
# Name: activity_day_time, dtype: int64

# %%
raw['activity_class_5min_extracted'] = raw['activity_class_5min'].apply(lambda x: x.decode('utf-8'))
raw.iloc[:3, :].T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> raw['activity_class_5min_extracted'] = raw['activity_class_5min'].apply(lambda x: x.decode('utf-8'))
#       <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> raw.iloc[:3, :].T
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# /Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> raw['activity_class_5min_extracted'] = raw['activity_class_5min'].apply(lambda x: x.decode('utf-8'))
#       <a href='vscode-notebook-cell:/Users/sehwan/Desktop/workspace/analyze_dementia/EDA.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> raw.iloc[:3, :].T
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
raw['activity_class_5min']
# Out:
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
#        ...
# 9700    ...
# 9701    ...
# 9702    ...
# 9703    ...
# 9704    ...
# Name: activity_class_5min, Length: 9705, dtype: object
